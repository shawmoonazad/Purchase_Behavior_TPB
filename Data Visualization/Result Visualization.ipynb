# %% [markdown]
# #Result comparision visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Creating a DataFrame
data = {
    'Attitude(ATTD)': [0.84, 0.82, 0.84, 0.84, 0.86, 0.84, 0.86, 0.86],
    'Subjective Naorm (SN)': [0.73, 0.70, 0.84, 0.84, 0.77, 0.77, 0.73, 0.77],
    'Perceived Behavoral Control(PBC)': [0.77, 0.77, 0.80, 0.84, 0.82, 0.77, 0.70, 0.77],
    'PBC & ATTD': [0.86, 0.82, 0.86, 0.86, 0.84, 0.85, 0.84, 0.84],
    'SN & ATTD': [0.89, 0.82, 0.86, 0.86, 0.86, 0.84, 0.86, 0.86],
    'SN & PBC': [0.77, 0.77, 0.80, 0.84, 0.80, 0.77, 0.75, 0.75],
    'ATTD & SN & PBC': [0.84, 0.82, 0.86, 0.86, 0.86, 0.89, 0.86, 0.91]
}

index = ['KNN', 'Decision Tree', 'Logistic Regression', 'Naive Bayes', 'SVM', 'Random Forest', 'Ada Boost', 'Gradient Boosting']

df = pd.DataFrame(data, index=index)
df = df.reset_index().melt('index', var_name='Metric', value_name='Accuracy')

# Initializing the figure and setting the theme
plt.figure(figsize=(10, 8))
sns.set_theme(style="whitegrid")

# Drawing a nested barplot
sns.barplot(x='Accuracy', y='index', hue='Metric', data=df, palette="bright")

# Setting the labels and title
plt.title('Algorithm Accuracies', fontsize=20)
plt.xlabel('Accuracy', fontsize=15)
plt.ylabel('Algorithm', fontsize=15)

# Positioning the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %% [markdown]
# #Result visualization using Radarplot

# %%
#importing libraries
import plotly.graph_objects as go

categories = ['KNN', 'Decision Tree', 'Logistic Regression', 'Naive Bayes', 'SVM', 'Random Forest', 'Ada Boost', 'Gradient Boosting']

fig = go.Figure()

fig.add_trace(go.Scatterpolar(
      r=[0.84, 0.82, 0.84, 0.84, 0.86, 0.84, 0.86, 0.86],
      theta=categories,
      fill='toself',
      name='Attitude(ATTD)'
))
fig.add_trace(go.Scatterpolar(
      r=[0.73, 0.70, 0.84, 0.84, 0.77, 0.77, 0.73, 0.77],
      theta=categories,
      fill='toself',
      name='Social Naorm (SN)'
))
fig.add_trace(go.Scatterpolar(
      r=[0.77, 0.77, 0.80, 0.84, 0.82, 0.77, 0.70, 0.77],
      theta=categories,
      fill='toself',
      name='Perceived Behavoral Control(PBC)'
))
fig.add_trace(go.Scatterpolar(
      r=[0.86, 0.82, 0.86, 0.86, 0.84, 0.85, 0.84, 0.84],
      theta=categories,
      fill='toself',
      name='Perceived Behavoral Control(PBC) & Attitude(ATTD)'
))
fig.add_trace(go.Scatterpolar(
      r=[0.89, 0.82, 0.86, 0.86, 0.86, 0.84, 0.86, 0.86],
      theta=categories,
      fill='toself',
      name='Social Naorm (SN) & Attitude(ATTD)'
))
fig.add_trace(go.Scatterpolar(
      r=[0.77, 0.77, 0.80, 0.84, 0.80, 0.77, 0.75, 0.75],
      theta=categories,
      fill='toself',
      name='Social Naorm (SN) & Perceived Behavoral Control(PBC)'
))
fig.add_trace(go.Scatterpolar(
      r=[0.84, 0.82, 0.86, 0.86, 0.86, 0.89, 0.86, 0.91],
      theta=categories,
      fill='toself',
      name='Attitude(ATTD) & Social Naorm (SN) & Perceived Behavoral Control(PBC)'
))
fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 1]
    )),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="777a7724-10a2-4d2b-ab1c-b883dd5881ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("777a7724-10a2-4d2b-ab1c-b883dd5881ec")) {                    Plotly.newPlot(                        "777a7724-10a2-4d2b-ab1c-b883dd5881ec",                        [{"fill":"toself","name":"Attitude(ATTD)","r":[0.84,0.82,0.84,0.84,0.86,0.84,0.86,0.86],"theta":["KNN","Decision Tree","Logistic Regression","Naive Bayes","SVM","Random Forest","Ada Boost","Gradient Boosting"],"type":"scatterpolar"},{"fill":"toself","name":"Social Naorm (SN)","r":[0.73,0.7,0.84,0.84,0.77,0.77,0.73,0.77],"theta":["KNN","Decision Tree","Logistic Regression","Naive Bayes","SVM","Random Forest","Ada Boost","Gradient Boosting"],"type":"scatterpolar"},{"fill":"toself","name":"Perceived Behavoral Control(PBC)","r":[0.77,0.77,0.8,0.84,0.82,0.77,0.7,0.77],"theta":["KNN","Decision Tree","Logistic Regression","Naive Bayes","SVM","Random Forest","Ada Boost","Gradient Boosting"],"type":"scatterpolar"},{"fill":"toself","name":"Perceived Behavoral Control(PBC) & Attitude(ATTD)","r":[0.86,0.82,0.86,0.86,0.84,0.85,0.84,0.84],"theta":["KNN","Decision Tree","Logistic Regression","Naive Bayes","SVM","Random Forest","Ada Boost","Gradient Boosting"],"type":"scatterpolar"},{"fill":"toself","name":"Social Naorm (SN) & Attitude(ATTD)","r":[0.89,0.82,0.86,0.86,0.86,0.84,0.86,0.86],"theta":["KNN","Decision Tree","Logistic Regression","Naive Bayes","SVM","Random Forest","Ada Boost","Gradient Boosting"],"type":"scatterpolar"},{"fill":"toself","name":"Social Naorm (SN) & Perceived Behavoral Control(PBC)","r":[0.77,0.77,0.8,0.84,0.8,0.77,0.75,0.75],"theta":["KNN","Decision Tree","Logistic Regression","Naive Bayes","SVM","Random Forest","Ada Boost","Gradient Boosting"],"type":"scatterpolar"},{"fill":"toself","name":"Attitude(ATTD) & Social Naorm (SN) & Perceived Behavoral Control(PBC)","r":[0.84,0.82,0.86,0.86,0.86,0.89,0.86,0.91],"theta":["KNN","Decision Tree","Logistic Regression","Naive Bayes","SVM","Random Forest","Ada Boost","Gradient Boosting"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"typ ...

# %% [markdown]
# ![Radar plot.png](data:image/png;base64,...)
